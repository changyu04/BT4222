# %%
import pandas as pd
import numpy as np
import pickle
import datetime as dt
import re
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
train = pd.read_csv("data/train.csv")
val = pd.read_csv("data/val.csv")
test = pd.read_csv("data/test.csv")

#merge everything into 1 dataframe
df = pd.concat([train, val, test], axis = 0)
df.drop("Unnamed: 0", axis = 1)
# Out:
#                                 id_review  \
# 0     ChZDSUhNMG9nS0VJQ0FnSUQ4bXFuSU53EAE
# 1     ChZDSUhNMG9nS0VJQ0FnSUQybFBEUVVREAE
# 2     ChZDSUhNMG9nS0VJQ0FnSUNBNnZfdUJ3EAE
# 3     ChZDSUhNMG9nS0VJQ0FnSURDak9tZ2NBEAE
# 4    ChdDSUhNMG9nS0VJQ0FnSUNNeTZhTmhRRRAB
# ..                                    ...
# 587  ChdDSUhNMG9nS0VJQ0FnSUN5OWFDY2tRRRAB
# 588  ChdDSUhNMG9nS0VJQ0FnSUMwb3Z5Q3h3RRAB
# 589  ChdDSUhNMG9nS0VJQ0FnSUNna0szN3VnRRAB
# 590  ChdDSUhNMG9nS0VJQ0FnSUNLNllIWTdRRRAB
# 591  ChdDSUhNMG9nS0VJQ0FnSURNMHAtYTlRRRAB
#
#                                                caption  relative_date  \
# 0    Staffs are rude. Food served cold. Clearly ove...    2 years ago
# 1    Overrated. Good for Instagram photos. Queue sy...  10 months ago
# 2    Really good cafe. Coffee is top rate, and food...    4 years ago
# 3    Good atmosphere but food wise taste was okay. ...    2 years ago
# 4                                      Very nice place    3 years ago
# ..                                                 ...            ...
# 587  Uncomfortable seating arrangement for 3pax and...    2 years ago
# 588  .................................................    3 years ago
# 589                                         Nice food.    4 years ago
# 590                                   Coffee was good.     a year ago
# 591                                 Very yummy Zi char    3 years ago
#
#     retrieval_date  rating            username  n_review_user  n_photo_user  \
# 0          48:59.1       2         Vanessa Nee              0             0
# 1          14:28.0       2            Gwen Goh              0             0
# 2          34:06.1       5  Jamie Rubbi-Clarke              0             0
# 3          10:18.9       3       Tan Ying Ying              0             0
# 4          35:10.2       4      G Gopal Chopra              0             0
# ..             ...     ...                 ...            ...           ...
# 587        09:20.2       2          Valerie NG              0             0
# 588        12:44.3       5   Trixie Maximillia              0             0
# 589        52:07.3       4             Din Din              0             0
# 590        24:48.9       5               J. S.              0             0
# 591        50:38.7       5            May Chan              0             0
#
#                                               url_user   restraunt_name  ...  \
# 0    https://www.google.com/maps/contrib/1081475767...           KokSen  ...
# 1    https://www.google.com/maps/contrib/1167846711...          Eggslut  ...
# 2    https://www.google.com/maps/contrib/1025726981...  PennyUniversity  ...
# 3    https://www.google.com/maps/contrib/1054935453...     WheelersYard  ...
# 4    https://www.google.com/maps/contrib/1100920581...          Hooters  ...
# ..                                                 ...              ...  ...
# 587  https://www.google.com/maps/contrib/1057667513...     WheelersYard  ...
# 588  https://www.google.com/maps/contrib/1092886785...     WheelersYard  ...
# 589  https://www.google.com/maps/contrib/1000114062...        Chichenti  ...
# 590  https://www.google.com/maps/contrib/1174774562...  PennyUniversity  ...
# 591  https://www.google.com/maps/contrib/1047262710...           KokSen  ...
#
#      other_sentiment                           food_aspect_extraction_1  \
# 0                 -1                                    food serve cold
# 1                  0                queue system confusing i dine order
# 2                  1  coffee top rate food also really good put lot ...
# 3                  1                taste okay visuall instagram worthy
# 4                  0                                     food delicious
# ..               ...                                                ...
# 587               -1                                                NaN
# 588                0                                                NaN
# 589                0                                          nice food
# 590                0                                        coffee good
# 591                0                                              yummy
#
#                            service_aspect_extraction_1  \
# 0                                           staff rude
# 1    person ask i takeout queue staff say free sit ...
# 2                      staff also friendly accommodate
# 3                                                  NaN
# 4                                        service great
# ..                                                 ...
# 587       uncomfortable seating arrangement 3pax group
# 588                                                NaN
# 589                                                NaN
# 590                                                NaN
# 591                                                NaN
#
#                           ambience_aspect_extraction_1  \
# 0                                                  NaN
# 1                        overrate good instagram photo
# 2                                       design overall
# 3                                      good atmosphere
# 4                                           nice place
# ..                                                 ...
# 587  seat huge table middle bar style hard conversa...
# 588                                                NaN
# 589                                                NaN
# 590                                                NaN
# 591                                                NaN
#
#     food_aspect_extraction_2        service_aspect_extraction_2  \
# 0                        NaN                                NaN
# 1                        NaN                                NaN
# 2                 coffee top  overall staff staff also friendly
# 3                  food wise                                NaN
# 4                        NaN                                NaN
# ..                       ...                                ...
# 587                      NaN                                NaN
# 588                      NaN                                NaN
# 589                nice food                                NaN
# 590                      NaN                                NaN
# 591                      NaN                                NaN
#
#     ambience_aspect_extraction_2 food_aspect_extraction_3  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2                            NaN  really good cafe coffee
# 3                good atmosphere                      NaN
# 4                     nice place                      NaN
# ..                           ...                      ...
# 587                          NaN                      NaN
# 588                          NaN                      NaN
# 589                          NaN                      NaN
# 590                          NaN           coffee wa good
# 591                          NaN                      NaN
#
#     service_aspect_extraction_3 ambience_aspect_extraction_3
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN              good atmosphere
# 4                           NaN                          NaN
# ..                          ...                          ...
# 587                         NaN                          NaN
# 588                         NaN                          NaN
# 589                         NaN                          NaN
# 590                         NaN                          NaN
# 591                         NaN                          NaN
#
# [3892 rows x 23 columns]

# %% [markdown]
# # sorting the dataframe by time
# - the dataset only contains relative date
#     - usually a number followed by "year" , "month", "hours" e.g ("2 years ago")
#     - or "a year ago"
#
# we want to convert them into dates

# %%
# text = "10 year ago"
# re.search("a [a-z]+",text).group(0)

# %%
retrieval_date = dt.datetime.today()
def get_review_date(text):
    # get the numbers
    if re.search("[0-9]+",text) != None:
        numbers_part = int(re.search("[0-9]+",text).group(0))
    else: 
        numbers_part = 1 # "if there is no number it means that the its 1 /year/month/day/hour/second" ago
    
    if "year" in text:
        return (retrieval_date - dt.timedelta(days = 365 * numbers_part)).date()
    elif "month" in text:
        return (retrieval_date - dt.timedelta(days = 30 * numbers_part)).date()
    elif "week" in text:
        return (retrieval_date - dt.timedelta(days = 7 * numbers_part)).date()
    elif "day" in text:
        return (retrieval_date - dt.timedelta(days = numbers_part)).date()
    elif "hour" in text:
        return (retrieval_date - dt.timedelta(hours= numbers_part)).date()
    elif "second" in text:
        return (retrieval_date - dt.timedelta(seconds= numbers_part)).date()
        
actual_date = df.relative_date.apply(lambda x : get_review_date(x))
df["date"] = pd.to_datetime(actual_date)
df
# Out:
#      Unnamed: 0                             id_review  \
# 0             0   ChZDSUhNMG9nS0VJQ0FnSUQ4bXFuSU53EAE
# 1             1   ChZDSUhNMG9nS0VJQ0FnSUQybFBEUVVREAE
# 2             2   ChZDSUhNMG9nS0VJQ0FnSUNBNnZfdUJ3EAE
# 3             3   ChZDSUhNMG9nS0VJQ0FnSURDak9tZ2NBEAE
# 4             4  ChdDSUhNMG9nS0VJQ0FnSUNNeTZhTmhRRRAB
# ..          ...                                   ...
# 587        3887  ChdDSUhNMG9nS0VJQ0FnSUN5OWFDY2tRRRAB
# 588        3888  ChdDSUhNMG9nS0VJQ0FnSUMwb3Z5Q3h3RRAB
# 589        3889  ChdDSUhNMG9nS0VJQ0FnSUNna0szN3VnRRAB
# 590        3890  ChdDSUhNMG9nS0VJQ0FnSUNLNllIWTdRRRAB
# 591        3891  ChdDSUhNMG9nS0VJQ0FnSURNMHAtYTlRRRAB
#
#                                                caption  relative_date  \
# 0    Staffs are rude. Food served cold. Clearly ove...    2 years ago
# 1    Overrated. Good for Instagram photos. Queue sy...  10 months ago
# 2    Really good cafe. Coffee is top rate, and food...    4 years ago
# 3    Good atmosphere but food wise taste was okay. ...    2 years ago
# 4                                      Very nice place    3 years ago
# ..                                                 ...            ...
# 587  Uncomfortable seating arrangement for 3pax and...    2 years ago
# 588  .................................................    3 years ago
# 589                                         Nice food.    4 years ago
# 590                                   Coffee was good.     a year ago
# 591                                 Very yummy Zi char    3 years ago
#
#     retrieval_date  rating            username  n_review_user  n_photo_user  \
# 0          48:59.1       2         Vanessa Nee              0             0
# 1          14:28.0       2            Gwen Goh              0             0
# 2          34:06.1       5  Jamie Rubbi-Clarke              0             0
# 3          10:18.9       3       Tan Ying Ying              0             0
# 4          35:10.2       4      G Gopal Chopra              0             0
# ..             ...     ...                 ...            ...           ...
# 587        09:20.2       2          Valerie NG              0             0
# 588        12:44.3       5   Trixie Maximillia              0             0
# 589        52:07.3       4             Din Din              0             0
# 590        24:48.9       5               J. S.              0             0
# 591        50:38.7       5            May Chan              0             0
#
#                                               url_user  ...  \
# 0    https://www.google.com/maps/contrib/1081475767...  ...
# 1    https://www.google.com/maps/contrib/1167846711...  ...
# 2    https://www.google.com/maps/contrib/1025726981...  ...
# 3    https://www.google.com/maps/contrib/1054935453...  ...
# 4    https://www.google.com/maps/contrib/1100920581...  ...
# ..                                                 ...  ...
# 587  https://www.google.com/maps/contrib/1057667513...  ...
# 588  https://www.google.com/maps/contrib/1092886785...  ...
# 589  https://www.google.com/maps/contrib/1000114062...  ...
# 590  https://www.google.com/maps/contrib/1174774562...  ...
# 591  https://www.google.com/maps/contrib/1047262710...  ...
#
#                               food_aspect_extraction_1  \
# 0                                      food serve cold
# 1                  queue system confusing i dine order
# 2    coffee top rate food also really good put lot ...
# 3                  taste okay visuall instagram worthy
# 4                                       food delicious
# ..                                                 ...
# 587                                                NaN
# 588                                                NaN
# 589                                          nice food
# 590                                        coffee good
# 591                                              yummy
#
#                            service_aspect_extraction_1  \
# 0                                           staff rude
# 1    person ask i takeout queue staff say free sit ...
# 2                      staff also friendly accommodate
# 3                                                  NaN
# 4                                        service great
# ..                                                 ...
# 587       uncomfortable seating arrangement 3pax group
# 588                                                NaN
# 589                                                NaN
# 590                                                NaN
# 591                                                NaN
#
#                           ambience_aspect_extraction_1  \
# 0                                                  NaN
# 1                        overrate good instagram photo
# 2                                       design overall
# 3                                      good atmosphere
# 4                                           nice place
# ..                                                 ...
# 587  seat huge table middle bar style hard conversa...
# 588                                                NaN
# 589                                                NaN
# 590                                                NaN
# 591                                                NaN
#
#      food_aspect_extraction_2        service_aspect_extraction_2  \
# 0                         NaN                                NaN
# 1                         NaN                                NaN
# 2                  coffee top  overall staff staff also friendly
# 3                   food wise                                NaN
# 4                         NaN                                NaN
# ..                        ...                                ...
# 587                       NaN                                NaN
# 588                       NaN                                NaN
# 589                 nice food                                NaN
# 590                       NaN                                NaN
# 591                       NaN                                NaN
#
#     ambience_aspect_extraction_2 food_aspect_extraction_3  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2                            NaN  really good cafe coffee
# 3                good atmosphere                      NaN
# 4                     nice place                      NaN
# ..                           ...                      ...
# 587                          NaN                      NaN
# 588                          NaN                      NaN
# 589                          NaN                      NaN
# 590                          NaN           coffee wa good
# 591                          NaN                      NaN
#
#     service_aspect_extraction_3 ambience_aspect_extraction_3       date
# 0                           NaN                          NaN 2021-04-04
# 1                           NaN                          NaN 2022-06-08
# 2                           NaN                          NaN 2019-04-05
# 3                           NaN              good atmosphere 2021-04-04
# 4                           NaN                          NaN 2020-04-04
# ..                          ...                          ...        ...
# 587                         NaN                          NaN 2021-04-04
# 588                         NaN                          NaN 2020-04-04
# 589                         NaN                          NaN 2019-04-05
# 590                         NaN                          NaN 2022-04-04
# 591                         NaN                          NaN 2020-04-04
#
# [3892 rows x 25 columns]

# %%
df.loc[df.food_aspect_extraction_2.isna(), "food_aspect_extraction_2"] = ""
df.loc[df.ambience_aspect_extraction_2.isna(), "ambience_aspect_extraction_2"] = ""
df.loc[df.service_aspect_extraction_2.isna(), "service_aspect_extraction_2"] = ""

# %% [markdown]
# # Getting the sentiment scores using our saved models

# %%
# load models that we want to use

food_model = pd.read_pickle("extraction_1_models/BOW_food_RF.pkg")
svc_model = pd.read_pickle("extraction_1_models/TFIDF_service_LgstcRegression.pkg")
ambience_model = pd.read_pickle("extraction_1_models/tfidf_ambience_XGB.pkg")


food_encoder = pd.read_pickle("extraction_1_models/encoding_bow_food.pkg") 
svc_encoder = pd.read_pickle("extraction_1_models/encoding_tfidf_service.pkg")
ambience_encoder = pd.read_pickle("extraction_1_models/encoding_tfidf_ambience.pkg")

# %%
df = df[["restraunt_name","date","food_aspect_extraction_2","service_aspect_extraction_2","ambience_aspect_extraction_2","rating"]]

# %%
# getting the sentimend scores using trained models
restraunts = df.restraunt_name.unique()

res = pd.DataFrame()

for restraunt in restraunts:
    
    # get the food 
    sub_df = df[df.restraunt_name == restraunt]
    food_sub_df = sub_df[["food_aspect_extraction_2","rating"]]
    svc_sub_df = sub_df[["service_aspect_extraction_2","rating"]]
    ambience_sub_df = sub_df[["ambience_aspect_extraction_2","rating"]]

    food_feature = food_encoder.transform(food_sub_df["food_aspect_extraction_2"]).toarray()
    food_feature = np.hstack([food_feature,food_sub_df.rating.to_numpy().reshape(-1,1)])
    sub_df["food_sentiment"] = food_model.predict(food_feature)

    svc_feature = svc_encoder.transform(svc_sub_df["service_aspect_extraction_2"]).toarray()
    svc_feature = np.hstack([svc_feature,svc_sub_df.rating.to_numpy().reshape(-1,1)])
    sub_df["service_sentiment"] = svc_model.predict(svc_feature)

    ambience_feature = ambience_encoder.transform(ambience_sub_df["ambience_aspect_extraction_2"]).toarray()
    ambience_feature = np.hstack([ambience_feature,ambience_sub_df.rating.to_numpy().reshape(-1,1)])
    sub_df["ambience_sentiment"] = ambience_model.predict(ambience_feature)

    res = pd.concat([res,sub_df], axis = 0)


res
# Out:
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["food_sentiment"] = food_model.predict(food_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["service_sentiment"] = svc_model.predict(svc_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["ambience_sentiment"] = ambience_model.predict(ambience_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["food_sentiment"] = food_model.predict(food_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["service_sentiment"] = svc_model.predict(svc_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["ambience_sentiment"] = ambience_model.predict(ambience_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["food_sentiment"] = food_model.predict(food_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["service_sentiment"] = svc_model.predict(svc_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["ambience_sentiment"] = ambience_model.predict(ambience_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["food_sentiment"] = food_model.predict(food_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["service_sentiment"] = svc_model.predict(svc_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["ambience_sentiment"] = ambience_model.predict(ambience_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["food_sentiment"] = food_model.predict(food_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["service_sentiment"] = svc_model.predict(svc_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["ambience_sentiment"] = ambience_model.predict(ambience_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["food_sentiment"] = food_model.predict(food_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["service_sentiment"] = svc_model.predict(svc_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["ambience_sentiment"] = ambience_model.predict(ambience_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["food_sentiment"] = food_model.predict(food_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["service_sentiment"] = svc_model.predict(svc_feature)
# /var/folders/vg/q5w3xdtj6cq6f0pfq2dpdgkh0000gn/T/ipykernel_42593/2632001005.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df["ambience_sentiment"] = ambience_model.predict(ambience_feature)
#     restraunt_name       date          food_aspect_extraction_2  \
# 0           KokSen 2021-04-04
# 18          KokSen 2023-03-21
# 35          KokSen 2022-12-05
# 38          KokSen 2023-02-03
# 47          KokSen 2020-04-04                         food okay
# ..             ...        ...                               ...
# 538       LolaCafe 2020-04-04
# 544       LolaCafe 2021-04-04                       nice coffee
# 548       LolaCafe 2017-04-05  somewhat good pastry good pastry
# 571       LolaCafe 2022-04-04
# 583       LolaCafe 2022-04-04
#
#     service_aspect_extraction_2 ambience_aspect_extraction_2  rating  \
# 0                                                                  2
# 18                                                                 5
# 35                                                                 4
# 38            service atrocious                                    1
# 47        service take too long                                    3
# ..                          ...                          ...     ...
# 538                                               place cozy       3
# 544                                                                4
# 548                                                                3
# 571              friendly staff                                    4
# 583                                                                4
#
#      food_sentiment  service_sentiment  ambience_sentiment
# 0                 0                  0                   0
# 18                1                  0                   0
# 35                1                  0                   0
# 38                0                 -1                   0
# 47                0                  0                   0
# ..              ...                ...                 ...
# 538               0                  0                   1
# 544               1                  0                   0
# 548               1                  0                   0
# 571               1                  1                   0
# 583               1                  0                   0
#
# [3892 rows x 9 columns]

# %%
#res[res.restraunt_name == "LolaCafe"].ambience_sentiment.value_counts()

# %%
#res.info()

# %% [markdown]
# # Aggregating the results across restraunts
# Estimated sentiment score for the $k^{th}$ review on a single aspect = $S_k \in \{-1,0,1\}$
#
# $$
# Score_{i,j} = \frac{\sum_{k = 1}^n{S}_{i,j,k}}{n} \quad i = aspect \ , j = restraunt
# $$

# %%
def calculate_score(x):
    sum_positive_and_negative = sum(x)
    count_positive_and_negative = len([i for i in x if i != 0])
    return sum_positive_and_negative/count_positive_and_negative

agg_food = pd.DataFrame(res.groupby("restraunt_name")["food_sentiment"].apply(lambda x : calculate_score(x)))
agg_svc = pd.DataFrame(res.groupby("restraunt_name")["service_sentiment"].apply(lambda x : calculate_score(x)))
agg_amb = pd.DataFrame(res.groupby("restraunt_name")["ambience_sentiment"].apply(lambda x : calculate_score(x)))
agg_results = pd.concat([agg_food, agg_svc, agg_amb], axis = 1)
agg_results
# Out:
#                  food_sentiment  service_sentiment  ambience_sentiment
# restraunt_name
# Chichenti              0.992366           0.760870            0.950617
# Eggslut                0.949020           0.560000            0.959184
# Hooters                0.985455           0.540230            0.969697
# KokSen                 0.977925           0.155556            0.900000
# LolaCafe               1.000000           0.812500            0.987730
# PennyUniversity        0.986928           0.480769            0.982456
# WheelersYard           0.972727           0.433333            1.000000

# %% [markdown]
# # Rank by food top 3

# %%
agg_results.sort_values("food_sentiment", ascending= False)[["food_sentiment"]][:3]
# Out:
#                  food_sentiment
# restraunt_name
# Chichenti              0.890411
# LolaCafe               0.883549
# PennyUniversity        0.813285

# %% [markdown]
# # Rank by serivce top 3

# %%
agg_results.sort_values("service_sentiment", ascending= False)[["service_sentiment"]][:3]
# Out:
#                 service_sentiment
# restraunt_name
# LolaCafe                 0.144177
# Hooters                  0.123037
# Chichenti                0.119863

# %% [markdown]
# # rank by ambience top 3

# %%
agg_results.sort_values("ambience_sentiment", ascending= False)[["ambience_sentiment"]][:3]
# Out:
#                  ambience_sentiment
# restraunt_name
# WheelersYard               0.319073
# LolaCafe                   0.297597
# PennyUniversity            0.201077

# %% [markdown]
# # Overtime

# %%
# create ones so that we can do a rolling count
res["x"] = np.ones(res.shape[0])

res_overtime = pd.DataFrame()

for restraunt in res.restraunt_name.unique():
    sub_df = res[res.restraunt_name == restraunt][["restraunt_name","date","food_sentiment","service_sentiment","ambience_sentiment","x"]]

    sub_df["food_senti_overtime"] = sub_df.food_sentiment.cumsum()/sub_df["x"].cumsum()
    sub_df["service_senti_overtime"] = sub_df.service_sentiment.cumsum()/sub_df["x"].cumsum()
    sub_df["ambience_senti_overtime"] = sub_df.ambience_sentiment.cumsum()/sub_df["x"].cumsum()
    sub_df = sub_df.drop(["food_sentiment","service_sentiment","ambience_sentiment","x"], axis = 1)
    res_overtime = pd.concat([res_overtime,sub_df], axis = 0)

res_overtime
# Out:
#     restraunt_name       date  food_senti_overtime  service_senti_overtime  \
# 0           KokSen 2021-04-04             0.000000                0.000000
# 18          KokSen 2023-03-21             0.500000                0.000000
# 35          KokSen 2022-12-05             0.666667                0.000000
# 38          KokSen 2023-02-03             0.500000               -0.250000
# 47          KokSen 2020-04-04             0.400000               -0.200000
# ..             ...        ...                  ...                     ...
# 538       LolaCafe 2020-04-04             0.882682                0.143389
# 544       LolaCafe 2021-04-04             0.882900                0.143123
# 548       LolaCafe 2017-04-05             0.883117                0.142857
# 571       LolaCafe 2022-04-04             0.883333                0.144444
# 583       LolaCafe 2022-04-04             0.883549                0.144177
#
#      ambience_senti_overtime
# 0                   0.000000
# 18                  0.000000
# 35                  0.000000
# 38                  0.000000
# 47                  0.000000
# ..                       ...
# 538                 0.299814
# 544                 0.299257
# 548                 0.298701
# 571                 0.298148
# 583                 0.297597
#
# [3892 rows x 5 columns]

# %%
res_overtime = res_overtime.sort_values(["restraunt_name","date"], ascending= True)
res_overtime = res_overtime.drop_duplicates(subset=["restraunt_name","date"], keep= "last") # one date could have many updates in scores, we just keep the first one, should give roughly the same results over a long period of time
res_overtime
# Out:
#      restraunt_name       date  food_senti_overtime  service_senti_overtime  \
# 594       Chichenti 2014-04-06             0.878049                0.146341
# 961       Chichenti 2015-04-06             0.893617                0.127660
# 562       Chichenti 2016-04-05             0.889845                0.118761
# 301       Chichenti 2017-04-05             0.875269                0.118280
# 107       Chichenti 2018-04-05             0.882239                0.119691
# ...             ...        ...                  ...                     ...
# 419    WheelersYard 2023-02-03             0.744589                0.045455
# 545    WheelersYard 2023-03-05             0.760870                0.047101
# 2030   WheelersYard 2023-03-21             0.711921                0.039735
# 1852   WheelersYard 2023-03-28             0.716312                0.039007
# 269    WheelersYard 2023-04-03             0.742529                0.045977
#
#       ambience_senti_overtime
# 594                  0.121951
# 961                  0.106383
# 562                  0.130809
# 301                  0.131183
# 107                  0.125483
# ...                       ...
# 419                  0.313853
# 545                  0.318841
# 2030                 0.324503
# 1852                 0.319149
# 269                  0.310345
#
# [147 rows x 5 columns]

# %% [markdown]
# # The scores are rescaled with standard scaler so that we can see compare the 3 sentiment on the same axis, the y -axis represents the scaled sentiment score

# %%
fig , ax = plt.subplots(7, figsize = (15,30))
count = 0
for restraunt in res_overtime.restraunt_name.unique():
    # abit difficult to see we have to scale all 3 scores 
    sub_df = res_overtime[res_overtime.restraunt_name == restraunt]

    scaler = StandardScaler()
    scaled_score = scaler.fit_transform(sub_df[["food_senti_overtime","service_senti_overtime","ambience_senti_overtime"]])

    ax[count].plot(sub_df.date, scaled_score[:,0] , label = "aggregate food sentiment")
    ax[count].plot(sub_df.date, scaled_score[:,1], label = "aggregate service sentiment")
    ax[count].plot(sub_df.date, scaled_score[:,2], label = "aggregate ambience sentiment")
    ax[count].legend()
    ax[count].set_title(restraunt)
    count += 1
